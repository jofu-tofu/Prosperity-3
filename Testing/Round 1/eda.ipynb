# %%
from importlib import reload
import sys
import os
sys.path.append(os.path.abspath('../'))
import util
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
reload(util)
dm2p = util.load_all_price_data(1)
util.spread_plot(dm2p,'SQUID_INK')

# %%
reload(util)
util.volume_plot(dm2p,'SQUID_INK')

# %%
util.get_vwap(dm2p,'SQUID_INK')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 util.get_vwap(dm2p,'SQUID_INK')
#
# File c:\Users\fujos\Github\Prosperity-3\Testing\util.py:83, in get_vwap(raw_data, min_vol)
#      81 def get_vwap(raw_data: pd.DataFrame, product: str, min_vol = 0) -> float:
#      82     raw_data = raw_data[raw_data['product'] == product]
# ---> 83     if 'timestamp' in raw_data.columns:
#      84         raw_data.set_index('timestamp', inplace=True)
#      85     order_vol = raw_data.filter(['ask_volume_1', 'ask_volume_2', 'ask_volume_3', 'bid_volume_1', 'bid_volume_2', 'bid_volume_3'])
#
# File c:\Users\fujos\anaconda3\envs\prosperity\Lib\site-packages\pandas\core\frame.py:10455, in DataFrame.map(self, func, na_action, **kwargs)
#   10452 def infer(x):
#   10453     return x._map_values(func, na_action=na_action)
# ...
